# %% [markdown]
# ## Observations and Insights
#
# * 'Capomulin' and 'Ramicane' were both measured the most and provided the most positive results for treatment of the tumors. This could indicate there was bias.
# * 'Capomulin' has a positive correlation with reducing the size of the tumor over timespan
# * The average tumor volumes in the tests with 'Capomulin' show that there is a positive correlation between the mouse weight and tumor size.

# %%
# Dependencies and Setup
try:
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    import scipy.stats as st
    import random
    print("All Modules Loaded!")
except:
    try:
        print("Module has failed to load. Trying to download.")
        # !pip install pandas
        # !pip install numpy
        # !pip install matplotlib
    except:
        print("Could not load a module... sorry")
# Out:
# All Modules Loaded!

# %%
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# %%
# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
# Combine the data into a single dataset
mouse_study_data = pd.merge(mouse_metadata, study_results, on='Mouse ID')
# Display the data table for preview
mouse_study_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
mice_count = len(mouse_study_data['Mouse ID'].unique())
mice_count
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
dupe_mice = [m_id
             # for the dataframe grouped by Mouse ID's, grab the Series Timepoint
             for m_id, timepoint in mouse_study_data.groupby('Mouse ID')['Timepoint'] 
             # if the timepoint's value counts have a max that is greater than one
             # then add that to the list, meaning if they have ANY duplicate Timepoints
             # then they must be a duplicate
             if timepoint.value_counts().max() > 1]
dupe_mice
# Out:
# ['g989']

# %%
# Optional: Get all the data for the duplicate mouse ID. 
data_dupe_mice = mouse_study_data.loc[mouse_study_data['Mouse ID'].isin(dupe_mice)]
data_dupe_mice
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
# this loop is to ignore this if the indexes have already been removed
for dupe_index in data_dupe_mice.index:
    if (dupe_index in mouse_study_data.index):
        mouse_study_data.drop(data_dupe_mice.index, inplace=True)
        break
mouse_study_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
mice_count = len(mouse_study_data['Mouse ID'].unique())
mice_count
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM (standard error of the mean) of the tumor volume for each regimen 

# Use groupby and summary statistical methods to calculate the following 
# properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

drug_regimen_columns = [['mean','median','var','std','sem'],
                        ['Mean','Median','Variance','Standard Deviation','SEM']]
drug_regimen_data = mouse_study_data.groupby(
    'Drug Regimen')['Tumor Volume (mm3)'].agg(
    drug_regimen_columns[0])
drug_regimen_data.columns = drug_regimen_columns[1]
drug_regimen_data
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013            6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken 
# on each drug regimen using pandas.

# this gets the absolute total measurements per each regimine,
# one for each and every data measurement
def get_absolute_total_measurements_per_regimen(data):
    drug_reg = 'Drug Regimen'
    df = pd.DataFrame()
    for name, group in mouse_study_data.groupby(drug_reg):
        measurements = 0
        # add 5 measurements per unique mouse
        # one for Mouse ID, Drug Regimen, Sex, Age_months, and Weight (g)
        measurements += group['Mouse ID'].nunique() * 5
        # add the non-null values for Timepoint
        measurements += group['Timepoint'].count()
        # add the non-null values for Tumor Volume (mm3)
        measurements += group['Tumor Volume (mm3)'].count()
        # add the non-null values for Metastatic Sites
        measurements += group['Metastatic Sites'].count()
        total_df = pd.DataFrame({drug_reg: [name],
                              'Total Measurements Taken': measurements})
        df = pd.concat([df, total_df])
    return df.set_index(drug_reg)

# get the measurements for each mouse, using the 'Timepoint' as the way to count
total_measurements_per_regimen = mouse_study_data.groupby('Drug Regimen')['Timepoint'].count()
total_measurements_per_regimen
# Out:
# Drug Regimen
# Capomulin    230
# Ceftamin     178
# Infubinol    178
# Ketapril     188
# Naftisol     186
# Placebo      181
# Propriva     148
# Ramicane     228
# Stelasyn     181
# Zoniferol    182
# Name: Timepoint, dtype: int64

# %%
# Generate a bar plot using Pandas's `DataFrame.plot()`
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.plot.html
total_measurements_per_regimen.plot(
    kind='bar',
    width=0.5,
    title='Total Measurements per Regimen',
    ylim=(0, max(total_measurements_per_regimen) * 1.1),
    xlabel='Drug Regimen', 
    ylabel='Measurements')
# Out:
# <AxesSubplot:title={'center':'Total Measurements per Regimen'}, xlabel='Drug Regimen', ylabel='Measurements'>

# %%
# Generate a bar plot using Matplotlib's `pyplot`
# https://matplotlib.org/3.3.3/api/_as_gen/matplotlib.pyplot.bar.html
plt.bar(
    x=np.arange(total_measurements_per_regimen.size),
    height=total_measurements_per_regimen.values,
    width=0.5)
plt.ylim(0, max(total_measurements_per_regimen) * 1.1)
plt.xticks(
    range(total_measurements_per_regimen.size), 
    total_measurements_per_regimen.index.values,
    rotation='vertical')
plt.margins(0.03)
plt.title('Total Measurements per Regimen')
plt.xlabel('Drug Regimen')
plt.ylabel('Measurements')
# Out:
# Text(0, 0.5, 'Measurements')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
distribution_sex = mouse_study_data['Sex'].value_counts()
distribution_sex.plot(     
    kind='bar',
    width=0.4,
    title='Total Measurements per Regimen',
    ylim=(0, max(distribution_sex) * 1.1),
    xlabel='Drug Regimen', 
    ylabel='Measurements')
# Out:
# <AxesSubplot:title={'center':'Total Measurements per Regimen'}, xlabel='Drug Regimen', ylabel='Measurements'>

# %%
plt.bar(
    x=np.arange(distribution_sex.size),
    height=distribution_sex.values,
    width=0.4)
plt.ylim(0, max(distribution_sex) * 1.1)
plt.xticks(
    range(distribution_sex.size), 
    distribution_sex.index.values,
    rotation='vertical')
plt.margins(0.2)
plt.title("Total Measurements per Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Measurements")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
distribution_sex.plot(     
    kind='pie',
    colors=['lightblue', 'pink'],
    title='Total Measurements per Regimen',
    ylabel='Measurements')
# Out:
# <AxesSubplot:title={'center':'Total Measurements per Regimen'}, ylabel='Measurements'>

# %%
fig1, ax1 = plt.subplots()
ax1.pie(
    distribution_sex.values, 
    labels=distribution_sex.index,
    colors=['lightblue', 'pink'])
plt.title("Total Measurements per Regimen")
plt.ylabel("Measurements")
# Out:
# Text(0, 0.5, 'Measurements')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# Get the data in the dataframe that are the final timepoints
def get_final_timepoints(data):
    tp = 'Timepoint'
    finals = pd.DataFrame()
    # group the data by mouse and drug
    for (drug, mouse), group in data.groupby(['Drug Regimen','Mouse ID']):
        # use the max timepoint value to get the whole row
        max_timepoint_row = group.loc[group[tp] == max(group[tp])]
        # add to finals
        finals = pd.concat([finals, max_timepoint_row])
    return finals

# get the final timepoints, then filter down 
# to 'Drug Regimen' and 'Tumor Volume (mm3)'
tumor_vol_by_drug = get_final_timepoints(mouse_study_data)[['Drug Regimen','Tumor Volume (mm3)']]
# set the index to 'Drug Regimen'
tumor_vol_by_drug.set_index('Drug Regimen', inplace=True)
# rename for clarity
tumor_vol_by_drug.rename(columns={'Tumor Volume (mm3)': "Final Tumor Volume (mm3)"}, inplace=True)
# display sumary just to see data
tumor_vol_by_drug.groupby('Drug Regimen').describe()
# Out:
#              Final Tumor Volume (mm3)                                   \
#                                 count       mean        std        min
# Drug Regimen
# Capomulin                        25.0  36.667568   5.715188  23.343598
# Ceftamin                         25.0  57.753977   8.365568  45.000000
# Infubinol                        25.0  58.178246   8.602957  36.321346
# Ketapril                         25.0  62.806191   9.945920  45.000000
# Naftisol                         25.0  61.205757  10.297083  45.000000
# Placebo                          25.0  60.508414   8.874672  45.000000
# Propriva                         24.0  56.493884   8.415626  45.000000
# Ramicane                         25.0  36.191390   5.671539  22.050126
# Stelasyn                         24.0  61.001707   9.504293  45.000000
# Zoniferol                        25.0  59.181258   8.767099  45.000000
#
#
#                     25%        50%        75%        max
# Drug Regimen
# ...

# %%
# Create boxplot to further see data
tumor_vol_by_drug.boxplot(
    by='Drug Regimen',                    
    column=['Final Tumor Volume (mm3)'], 
    grid = False,
    rot=90,
    fontsize=10)
plt.title('Final Tumor Volume of Mouse\nper Drug Regimen', fontsize=18)
plt.suptitle('')
plt.ylabel('Tumor Volume (mm3)')
plt.show()

# %%
# Put treatments into a list for for loop (and later for plot labels)
show_treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Calculate the IQR and quantitatively determine if there are any potential outliers
def filter_outliers(values):
    # Create empty list to fill with tumor vol data (for plotting)
    filtered_values = []
    # get the quartile data
    q1 = np.quantile(values, 0.25)
    q3 = np.quantile(values, 0.75)
    iqr = q3 - q1
    #print(f'q1 {q1}, q3 {q3}, iqr {iqr}')
    for value in values:
        # Determine outliers using upper and lower bounds
        v_min = q1 - 1.5 * iqr
        v_max = q3 + 1.5 * iqr
        #print(f'value {value}, v_min {v_min}, v_max {v_max}')
        if (value < v_min) or (value > v_max):
            continue        
        else: # else, add the data
            filtered_values.append(value)
    # return filted values
    return filtered_values

# Filter out the outliers in the data sent in
def get_cleaned_tumor_vol_by_drug(data, remove_outliers=False, only_show=None):
    tumor_vol_by_drug = pd.DataFrame()
    for name, group in data.groupby('Drug Regimen')['Tumor Volume (mm3)']:
        # skip out the groups not in only_show
        if only_show and name not in only_show:
            continue
        tumor_vols = filter_outliers(group.values) if remove_outliers else group.values
        drug_vols = pd.DataFrame({'Drug Regimen': [name for n in tumor_vols],
                                  'Final Tumor Volume (mm3)':tumor_vols})
        tumor_vol_by_drug = pd.concat([tumor_vol_by_drug, drug_vols])
    return tumor_vol_by_drug.set_index('Drug Regimen')
    
tumor_vol_by_drug = get_cleaned_tumor_vol_by_drug(get_final_timepoints(mouse_study_data), 
                                                  remove_outliers=True,
                                                  only_show=show_treatments)

# display some info, just to see what's going on
tumor_vol_by_drug.groupby('Drug Regimen').describe()
# Out:
#              Final Tumor Volume (mm3)                                  \
#                                 count       mean       std        min
# Drug Regimen
# Capomulin                        25.0  36.667568  5.715188  23.343598
# Ceftamin                         25.0  57.753977  8.365568  45.000000
# Infubinol                        24.0  59.088950  7.456050  45.699331
# Ramicane                         25.0  36.191390  5.671539  22.050126
#
#
#                     25%        50%        75%        max
# Drug Regimen
# Capomulin     32.377357  38.125164  40.159220  47.685963
# Ceftamin      48.722078  59.851956  64.299830  68.923185
# Infubinol     54.504563  60.541973  65.665074  72.226731
# Ramicane      31.560470  36.561652  40.659006  45.220869

# %%
# Generate a box plot of the final tumor volume of each
# mouse across four regimens of interest

def get_treatments_data(tumor_vol_by_drug, treatments):
    data = []
    # add each treatment in same order
    for i in range(len(treatments)):
        tumor_vol = tumor_vol_by_drug.loc[treatments[i]]
        data.append(tumor_vol['Final Tumor Volume (mm3)'].values)
    return data

treatments_data = get_treatments_data(tumor_vol_by_drug,show_treatments)

fig = plt.figure() 
ax = fig.add_axes([0, 0, 1, 1]) 
bp = ax.boxplot(treatments_data) 
plt.title('Final Tumor Volume of Mouse\nper Drug Regimen', fontsize=18)
plt.xlabel('Drug Regimen')
plt.ylabel('Final Tumor Volume (mm3)')
plt.xticks(
    [n + 1 for n in range(len(show_treatments))], 
    show_treatments)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
drug_filter = 'Capomulin'

# get the tumor volume vs. time point for a mouse for a spesific drug
def get_tumor_vol_vs_timepoint(data, drug, mouse=float('inf')):
    # filter out nessisary data
    df = data[['Drug Regimen','Mouse ID','Timepoint','Tumor Volume (mm3)']]
    # filter out selected drug
    drug_df = df.loc[df['Drug Regimen'] == drug]
    # get all mice names
    mice = drug_df['Mouse ID'].unique()
    mouse_id = ''
    # ifs have value for mouse, use that value
    if (abs(mouse) >= len(mice)):
        mouse_id = random.choice(mice)
    else:
        # if anything goes wrong, set to default 0
        try:
            mouse_id = mice[mouse]
        except:
            mouse_id = mice[0]
    # return the corresponding mouse id
    return drug_df.loc[drug_df['Mouse ID'] == mouse_id]

tumor_vol_vs_timepoint = get_tumor_vol_vs_timepoint(
    mouse_study_data,
    'Capomulin')

x_values = tumor_vol_vs_timepoint['Timepoint']
y_values = tumor_vol_vs_timepoint['Tumor Volume (mm3)']
plt.plot(x_values, y_values)
plt.title('Tumor volume vs. time point for a\nmouse treated with Capomulin', fontsize=18)
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (mm3)')
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# send back the average tumor volume vs. mouse weight with the sent in
# drug name
def get_avg_tumor_vol_vs_mouse_weight(data, drug):
    df = data[['Drug Regimen','Mouse ID','Tumor Volume (mm3)','Weight (g)']]
    drug_df = df.loc[df['Drug Regimen'] == drug]
    return drug_df.groupby('Mouse ID').mean()

avg_tumor_vol_vs_mouse_weight = get_avg_tumor_vol_vs_mouse_weight(mouse_study_data,'Capomulin')
x_values = avg_tumor_vol_vs_mouse_weight['Weight (g)']
y_values = avg_tumor_vol_vs_mouse_weight['Tumor Volume (mm3)']
plt.scatter(x_values,y_values)
plt.title('Average tumor volume vs. mouse weight\nfor the Capomulin regimen', fontsize=18)
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (mm3)')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

avg_tumor_vol_vs_mouse_weight = get_avg_tumor_vol_vs_mouse_weight(mouse_study_data,'Capomulin')
x_values = avg_tumor_vol_vs_mouse_weight['Weight (g)']
y_values = avg_tumor_vol_vs_mouse_weight['Tumor Volume (mm3)']
(slope,intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
print()
regress_values = x_values * slope + intercept
line_eq = f'y = {round(slope, 2)}x + {round(intercept, 2)}'
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values, 'r-')
plt.annotate(line_eq, (20,38),fontsize=15,color='red')
plt.title('Average tumor volume vs. mouse weight\nfor the Capomulin regimen', fontsize=18)
plt.xlabel('Weight (g)')
plt.ylabel('Tumor Volume (mm3)')
plt.show()
print(f'The r-squared(correlation coefficient) is {rvalue**2}')
# Out:
# The r-squared(correlation coefficient) is 0.7088568047708717
